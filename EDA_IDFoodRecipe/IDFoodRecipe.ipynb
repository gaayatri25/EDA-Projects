# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
import os #for interacting with os
import glob #to get a list of files matching a pattern

# %%
#Read all of the csv's

extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]

# %%
print(all_filenames)
# Out:
# ['dataset-tempe.csv', 'dataset-ayam.csv', 'dataset-udang.csv', 'dataset-kambing.csv', 'dataset-ikan.csv', 'dataset-telur.csv', 'dataset-tahu.csv', 'dataset-sapi.csv']

# %%
#Combine all of the files
combined_datafood2 = pd.concat([pd.read_csv(f) for f in all_filenames ])

# %%
#export to csv
combined_datafood2.to_csv('combined_datafood2.csv', index=False, encoding='utf-8-sig')

# %%
df = pd.read_csv('combined_datafood2.csv')

# %%
df.head()
# Out:
#                                  Title  \
# 0  Orek tempe manis pedas super simple
# 1               Terik ayam tempe telor
# 2    Penyet Tempe Sambel Korek Kemangi
# 3                         Nugget tempe
# 4                  Tempe tepung sajiku
#
#                                          Ingredients  \
# 0  Tempe (saya beli 3000 saja)--3 buah cabe gendo...
# 1  4 sayap ayam--4 buah telor--1/2 papan tempe--B...
# 2  2 buah tempe--1 genggam Daun kemangi--15 cabe ...
# 3  1 papan tempe dihaluskan(saya kukus dlu)--1 bu...
# 4  1 potong tempe 3000--1 bngkus sajiku tepung se...
#
#                                                Steps  Loves  \
# 0  Potong2 tempe sesuai selera lalu goreng sebent...      7
# 1  Cuci sayap ayam kemudian sisihkan. Rebus telur...      6
# 2  Iris tempe jd beberapa potong, bumbui dg bawan...      8
# 3  Campur tempe,wortel,daun bawang & bumbu yg sud...      8
# 4  Potong tempe tipis2--Tuang tepung lalu beri ai...      1
#
#                                                  URL
# 0  /id/resep/4474061-orek-tempe-manis-pedas-super...
# 1           /id/resep/4474066-terik-ayam-tempe-telor
# 2  /id/resep/4473809-penyet-tempe-sambel-korek-ke...
# 3                     /id/resep/4473715-nugget-tempe
# 4              /id/resep/4473463-tempe-tepung-sajiku

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15641 entries, 0 to 15640
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Title        15641 non-null  object
#  1   Ingredients  15593 non-null  object
#  2   Steps        15595 non-null  object
#  3   Loves        15641 non-null  int64
#  4   URL          15641 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 611.1+ KB

# %%
df.shape
# Out:
# (15641, 5)

# %%
#let's see the null values
a = df.isnull().sum()
print(a)
# Out:
# Title           0
# Ingredients    48
# Steps          46
# Loves           0
# URL             0
# dtype: int64

# %% [markdown]
# Column Ingredients has 48 null values

# %% [markdown]
# the null values in column Ingredients:

# %%
df[df['Ingredients'].isnull()]
# Out:
#                       Title Ingredients  \
# 1143   Balado telor + tempe         NaN
# 2241              [Notitle]         NaN
# 2244              [Notitle]         NaN
# 2284              [Notitle]         NaN
# 2288              [Notitle]         NaN
# 2450              [Notitle]         NaN
# 2507              [Notitle]         NaN
# 2509              [Notitle]         NaN
# 2510              [Notitle]         NaN
# 2821              [Notitle]         NaN
# 2835              [Notitle]         NaN
# 2836              [Notitle]         NaN
# 2919              [Notitle]         NaN
# 3065              [Notitle]         NaN
# 3300              [Notitle]         NaN
# 3785              [Notitle]         NaN
# 6090              [Notitle]         NaN
# 6152              [Notitle]         NaN
# 6155              [Notitle]         NaN
# 6156              [Notitle]         NaN
# 6177              [Notitle]         NaN
# 6532              [Notitle]         NaN
# 6578              [Notitle]         NaN
# 6712              [Notitle]         NaN
# 6893              [Notitle]         NaN
# 6994              [Notitle]         NaN
# 7099              [Notitle]         NaN
# 7406              [Notitle]         NaN
# 7428              [Notitle]         NaN
# 10029             [Notitle]         NaN
# 10159             [Notitle]         NaN
# 13299       Tahu tumis toge         NaN
# 13689             [Notitle]         NaN
# 13904             [Notitle]         NaN
# 13915             [Notitle]         NaN
# 14420             [Notitle]         NaN
# 14446             [Notitle]         NaN
# 14448             [Notitle]         NaN
# 14449             [Notitle]         NaN
# 14450             [Notitle]         NaN
# 14451             [Notitle]         NaN
# 14452             [Notitle]         NaN
# 14466             [Notitle]         NaN
# 14467             [Notitle]         NaN
# 14590             [Notitle]         NaN
# 14591             [Notitle]         NaN
# 14592             [Notitle]         NaN
# 14593             [Notitle]         NaN
#
#                                                    Steps  Loves  \
# 1143   Bumbu cabe merah bawang merah 5 buah tomat 1 b...     16
# 2241                                                 NaN      0
# 2244                                                 NaN      0
# 2284                                                 NaN      0
# 2288                                                 NaN      0
# 2450                                                 NaN      0
# 2507                                                 NaN      0
# 2509                                                 NaN      0
# 2510                                                 NaN      0
# 2821                                                 NaN      0
# 2835                                                 NaN      0
# 2836                                                 NaN      0
# 2919                                                 NaN      0
# 3065                                                 NaN      0
# 3300                                                 NaN      0
# 3785                                                 NaN      0
# 6090                                                 NaN      0
# 6152                                                 NaN      0
# 6155                                                 NaN      0
# 6156                                                 NaN      0
# 6177                                                 NaN      0
# 6532                                                 NaN      0
# 6578                                                 NaN      0
# 6712                                                 NaN      0
# 6893                                                 NaN      0
# 6994                                                 NaN      0
# 7099                                                 NaN      0
# 7406                                                 NaN      0
# 7428                                                 NaN      0
# 10029                                                NaN      0
# 10159                                                NaN      0
# 13299  Potong2 tahu lalu di--Potong bawang merah+ put...     16
# 13689                                                NaN      0
# 13904                                                NaN      0
# 13915                                                NaN      0
# 14420                                                NaN      0
# 14446                                                NaN      0
# 14448                                                NaN      0
# 14449                                                NaN      0
# 14450                                                NaN      0
# 14451                                                NaN      0
# 14452                                                NaN      0
# 14466                                                NaN      0
# 14467                                                NaN      0
# 14590                                                NaN      0
# 14591                                                NaN      0
# 14592                                                NaN      0
# 14593                                                NaN      0
#
#                                                      URL
# 1143                /id/resep/4222488-balado-telor-tempe
# 2241                        /id/resep/4459283-ayam-bakar
# 2244               /id/resep/4458951-sate-ayam-maknyusss
# 2284          /id/resep/4454787-garang-asam-ayam-kampung
# 2288                       /id/resep/4454903-ayam-kremes
# 2450                /id/resep/4444134-ayam-balado-simple
# 2507                     /id/resep/4442538-perkedel-ayam
# 2509        /id/resep/4442319-chicken-wings-saos-mentega
# 2510                   /id/resep/4442267-ayam-sambal-ijo
# 2821                    /id/resep/4410020-ayam-terriyaki
# 2835   /id/resep/4409498-mie-ayam-homemade-ala-mama-n...
# 2836   /id/resep/4409320-salted-egg-yolk-chicken-simp...
# 2919                           /id/resep/4396883-ayam-rw
# 3065                           /id/resep/4377584-mi-ayam
# 3300           /id/resep/4363996-ayam-gocap-goreng-kecap
# 3785                    /id/resep/4324179-sup-ceker-ayam
# 6090   /id/resep/3409967-sate-kambing-kecap-manis-sim...
# 6152   /id/resep/3334665-nasi-goreng-daur-ulang-gule-...
# 6155                /id/resep/3302954-gule-kambing-yummy
# 6156                     /id/resep/3302724-gulai-kambing
# 6177   /id/resep/3298588-nasi-kebuli-kambing-kitaberbagi
# 6532    /id/resep/3270914-nasgor-kambing-ala-kebon-sirih
# 6578                      /id/resep/3268926-sate-kambing
# 6712   /id/resep/2465947-nasi-kebuli-kambing-ala-bund...
# 6893                  /id/resep/1132705-tongseng-kambing
# 6994        /id/resep/967173-daging-kambing-bumbu-kuning
# 7099   /id/resep/955137-tumis-daging-kambing-setan-si...
# 7406                             /id/resep/4277212-maraq
# 7428    /id/resep/3918264-nasi-kebuli-ayam-ala-nusantara
# 10029  /id/resep/4395911-telor-ceplok-dicabein-kisahk...
# 10159              /id/resep/4361542-balado-telur-ceplok
# 13299                  /id/resep/4216152-tahu-tumis-toge
# 13689         /id/resep/4471696-brokoli-sapi-cah-paprika
# 13904  /id/resep/4335141-tumis-daging-lemak-sapi-keto...
# 13915                /id/resep/4324037-nugget-udang-sapi
# 14420  /id/resep/3920063-beef-blackpaper-with-green-c...
# 14446         /id/resep/3905717-beef-teriyaki-ala-hokben
# 14448          /id/resep/3902717-sapi-lada-hitam-spesial
# 14449          /id/resep/3898125-beef-in-blackbean-sauce
# 14450                     /id/resep/3900516-rendang-sapi
# 14451       /id/resep/3900657-rendang-daging-sapi-simple
# 14452   /id/resep/3900664-gulai-kacang-merah-daging-sapi
# 14466                     /id/resep/3895985-rendang-sapi
# 14467  /id/resep/3895293-spaghetti-beef-marinara-pr_p...
# 14590  /id/resep/3812687-semur-tulang-daging-sapi-dan...
# 14591            /id/resep/3810864-oseng-kikil-sapi-tahu
# 14592                  /id/resep/3812346-sapi-lada-hitam
# 14593  /id/resep/3810985-bubur-lembut-sapi-slow-cooke...

# %% [markdown]
# Column Steps has 46 null values

# %% [markdown]
# the null values in column Steps:

# %%
df[df['Steps'].isnull()]
# Out:
#            Title Ingredients Steps  Loves  \
# 2241   [Notitle]         NaN   NaN      0
# 2244   [Notitle]         NaN   NaN      0
# 2284   [Notitle]         NaN   NaN      0
# 2288   [Notitle]         NaN   NaN      0
# 2450   [Notitle]         NaN   NaN      0
# 2507   [Notitle]         NaN   NaN      0
# 2509   [Notitle]         NaN   NaN      0
# 2510   [Notitle]         NaN   NaN      0
# 2821   [Notitle]         NaN   NaN      0
# 2835   [Notitle]         NaN   NaN      0
# 2836   [Notitle]         NaN   NaN      0
# 2919   [Notitle]         NaN   NaN      0
# 3065   [Notitle]         NaN   NaN      0
# 3300   [Notitle]         NaN   NaN      0
# 3785   [Notitle]         NaN   NaN      0
# 6090   [Notitle]         NaN   NaN      0
# 6152   [Notitle]         NaN   NaN      0
# 6155   [Notitle]         NaN   NaN      0
# 6156   [Notitle]         NaN   NaN      0
# 6177   [Notitle]         NaN   NaN      0
# 6532   [Notitle]         NaN   NaN      0
# 6578   [Notitle]         NaN   NaN      0
# 6712   [Notitle]         NaN   NaN      0
# 6893   [Notitle]         NaN   NaN      0
# 6994   [Notitle]         NaN   NaN      0
# 7099   [Notitle]         NaN   NaN      0
# 7406   [Notitle]         NaN   NaN      0
# 7428   [Notitle]         NaN   NaN      0
# 10029  [Notitle]         NaN   NaN      0
# 10159  [Notitle]         NaN   NaN      0
# 13689  [Notitle]         NaN   NaN      0
# 13904  [Notitle]         NaN   NaN      0
# 13915  [Notitle]         NaN   NaN      0
# 14420  [Notitle]         NaN   NaN      0
# 14446  [Notitle]         NaN   NaN      0
# 14448  [Notitle]         NaN   NaN      0
# 14449  [Notitle]         NaN   NaN      0
# 14450  [Notitle]         NaN   NaN      0
# 14451  [Notitle]         NaN   NaN      0
# 14452  [Notitle]         NaN   NaN      0
# 14466  [Notitle]         NaN   NaN      0
# 14467  [Notitle]         NaN   NaN      0
# 14590  [Notitle]         NaN   NaN      0
# 14591  [Notitle]         NaN   NaN      0
# 14592  [Notitle]         NaN   NaN      0
# 14593  [Notitle]         NaN   NaN      0
#
#                                                      URL
# 2241                        /id/resep/4459283-ayam-bakar
# 2244               /id/resep/4458951-sate-ayam-maknyusss
# 2284          /id/resep/4454787-garang-asam-ayam-kampung
# 2288                       /id/resep/4454903-ayam-kremes
# 2450                /id/resep/4444134-ayam-balado-simple
# 2507                     /id/resep/4442538-perkedel-ayam
# 2509        /id/resep/4442319-chicken-wings-saos-mentega
# 2510                   /id/resep/4442267-ayam-sambal-ijo
# 2821                    /id/resep/4410020-ayam-terriyaki
# 2835   /id/resep/4409498-mie-ayam-homemade-ala-mama-n...
# 2836   /id/resep/4409320-salted-egg-yolk-chicken-simp...
# 2919                           /id/resep/4396883-ayam-rw
# 3065                           /id/resep/4377584-mi-ayam
# 3300           /id/resep/4363996-ayam-gocap-goreng-kecap
# 3785                    /id/resep/4324179-sup-ceker-ayam
# 6090   /id/resep/3409967-sate-kambing-kecap-manis-sim...
# 6152   /id/resep/3334665-nasi-goreng-daur-ulang-gule-...
# 6155                /id/resep/3302954-gule-kambing-yummy
# 6156                     /id/resep/3302724-gulai-kambing
# 6177   /id/resep/3298588-nasi-kebuli-kambing-kitaberbagi
# 6532    /id/resep/3270914-nasgor-kambing-ala-kebon-sirih
# 6578                      /id/resep/3268926-sate-kambing
# 6712   /id/resep/2465947-nasi-kebuli-kambing-ala-bund...
# 6893                  /id/resep/1132705-tongseng-kambing
# 6994        /id/resep/967173-daging-kambing-bumbu-kuning
# 7099   /id/resep/955137-tumis-daging-kambing-setan-si...
# 7406                             /id/resep/4277212-maraq
# 7428    /id/resep/3918264-nasi-kebuli-ayam-ala-nusantara
# 10029  /id/resep/4395911-telor-ceplok-dicabein-kisahk...
# 10159              /id/resep/4361542-balado-telur-ceplok
# 13689         /id/resep/4471696-brokoli-sapi-cah-paprika
# 13904  /id/resep/4335141-tumis-daging-lemak-sapi-keto...
# 13915                /id/resep/4324037-nugget-udang-sapi
# 14420  /id/resep/3920063-beef-blackpaper-with-green-c...
# 14446         /id/resep/3905717-beef-teriyaki-ala-hokben
# 14448          /id/resep/3902717-sapi-lada-hitam-spesial
# 14449          /id/resep/3898125-beef-in-blackbean-sauce
# 14450                     /id/resep/3900516-rendang-sapi
# 14451       /id/resep/3900657-rendang-daging-sapi-simple
# 14452   /id/resep/3900664-gulai-kacang-merah-daging-sapi
# 14466                     /id/resep/3895985-rendang-sapi
# 14467  /id/resep/3895293-spaghetti-beef-marinara-pr_p...
# 14590  /id/resep/3812687-semur-tulang-daging-sapi-dan...
# 14591            /id/resep/3810864-oseng-kikil-sapi-tahu
# 14592                  /id/resep/3812346-sapi-lada-hitam
# 14593  /id/resep/3810985-bubur-lembut-sapi-slow-cooke...

# %% [markdown]
# If we notice, the column Title has '[NoTitle]' value:

# %%
df[df['Title'].str.contains('Notitle', case=True)]
# Out:
#            Title Ingredients Steps  Loves  \
# 2241   [Notitle]         NaN   NaN      0
# 2244   [Notitle]         NaN   NaN      0
# 2284   [Notitle]         NaN   NaN      0
# 2288   [Notitle]         NaN   NaN      0
# 2450   [Notitle]         NaN   NaN      0
# 2507   [Notitle]         NaN   NaN      0
# 2509   [Notitle]         NaN   NaN      0
# 2510   [Notitle]         NaN   NaN      0
# 2821   [Notitle]         NaN   NaN      0
# 2835   [Notitle]         NaN   NaN      0
# 2836   [Notitle]         NaN   NaN      0
# 2919   [Notitle]         NaN   NaN      0
# 3065   [Notitle]         NaN   NaN      0
# 3300   [Notitle]         NaN   NaN      0
# 3785   [Notitle]         NaN   NaN      0
# 6090   [Notitle]         NaN   NaN      0
# 6152   [Notitle]         NaN   NaN      0
# 6155   [Notitle]         NaN   NaN      0
# 6156   [Notitle]         NaN   NaN      0
# 6177   [Notitle]         NaN   NaN      0
# 6532   [Notitle]         NaN   NaN      0
# 6578   [Notitle]         NaN   NaN      0
# 6712   [Notitle]         NaN   NaN      0
# 6893   [Notitle]         NaN   NaN      0
# 6994   [Notitle]         NaN   NaN      0
# 7099   [Notitle]         NaN   NaN      0
# 7406   [Notitle]         NaN   NaN      0
# 7428   [Notitle]         NaN   NaN      0
# 10029  [Notitle]         NaN   NaN      0
# 10159  [Notitle]         NaN   NaN      0
# 13689  [Notitle]         NaN   NaN      0
# 13904  [Notitle]         NaN   NaN      0
# 13915  [Notitle]         NaN   NaN      0
# 14420  [Notitle]         NaN   NaN      0
# 14446  [Notitle]         NaN   NaN      0
# 14448  [Notitle]         NaN   NaN      0
# 14449  [Notitle]         NaN   NaN      0
# 14450  [Notitle]         NaN   NaN      0
# 14451  [Notitle]         NaN   NaN      0
# 14452  [Notitle]         NaN   NaN      0
# 14466  [Notitle]         NaN   NaN      0
# 14467  [Notitle]         NaN   NaN      0
# 14590  [Notitle]         NaN   NaN      0
# 14591  [Notitle]         NaN   NaN      0
# 14592  [Notitle]         NaN   NaN      0
# 14593  [Notitle]         NaN   NaN      0
#
#                                                      URL
# 2241                        /id/resep/4459283-ayam-bakar
# 2244               /id/resep/4458951-sate-ayam-maknyusss
# 2284          /id/resep/4454787-garang-asam-ayam-kampung
# 2288                       /id/resep/4454903-ayam-kremes
# 2450                /id/resep/4444134-ayam-balado-simple
# 2507                     /id/resep/4442538-perkedel-ayam
# 2509        /id/resep/4442319-chicken-wings-saos-mentega
# 2510                   /id/resep/4442267-ayam-sambal-ijo
# 2821                    /id/resep/4410020-ayam-terriyaki
# 2835   /id/resep/4409498-mie-ayam-homemade-ala-mama-n...
# 2836   /id/resep/4409320-salted-egg-yolk-chicken-simp...
# 2919                           /id/resep/4396883-ayam-rw
# 3065                           /id/resep/4377584-mi-ayam
# 3300           /id/resep/4363996-ayam-gocap-goreng-kecap
# 3785                    /id/resep/4324179-sup-ceker-ayam
# 6090   /id/resep/3409967-sate-kambing-kecap-manis-sim...
# 6152   /id/resep/3334665-nasi-goreng-daur-ulang-gule-...
# 6155                /id/resep/3302954-gule-kambing-yummy
# 6156                     /id/resep/3302724-gulai-kambing
# 6177   /id/resep/3298588-nasi-kebuli-kambing-kitaberbagi
# 6532    /id/resep/3270914-nasgor-kambing-ala-kebon-sirih
# 6578                      /id/resep/3268926-sate-kambing
# 6712   /id/resep/2465947-nasi-kebuli-kambing-ala-bund...
# 6893                  /id/resep/1132705-tongseng-kambing
# 6994        /id/resep/967173-daging-kambing-bumbu-kuning
# 7099   /id/resep/955137-tumis-daging-kambing-setan-si...
# 7406                             /id/resep/4277212-maraq
# 7428    /id/resep/3918264-nasi-kebuli-ayam-ala-nusantara
# 10029  /id/resep/4395911-telor-ceplok-dicabein-kisahk...
# 10159              /id/resep/4361542-balado-telur-ceplok
# 13689         /id/resep/4471696-brokoli-sapi-cah-paprika
# 13904  /id/resep/4335141-tumis-daging-lemak-sapi-keto...
# 13915                /id/resep/4324037-nugget-udang-sapi
# 14420  /id/resep/3920063-beef-blackpaper-with-green-c...
# 14446         /id/resep/3905717-beef-teriyaki-ala-hokben
# 14448          /id/resep/3902717-sapi-lada-hitam-spesial
# 14449          /id/resep/3898125-beef-in-blackbean-sauce
# 14450                     /id/resep/3900516-rendang-sapi
# 14451       /id/resep/3900657-rendang-daging-sapi-simple
# 14452   /id/resep/3900664-gulai-kacang-merah-daging-sapi
# 14466                     /id/resep/3895985-rendang-sapi
# 14467  /id/resep/3895293-spaghetti-beef-marinara-pr_p...
# 14590  /id/resep/3812687-semur-tulang-daging-sapi-dan...
# 14591            /id/resep/3810864-oseng-kikil-sapi-tahu
# 14592                  /id/resep/3812346-sapi-lada-hitam
# 14593  /id/resep/3810985-bubur-lembut-sapi-slow-cooke...

# %% [markdown]
# Change the null value in column Ingredients:

# %%
df['Ingredients'].fillna('NoIngrediens', inplace=True)

# %%
df.isnull().sum()
# Out:
# Title           0
# Ingredients     0
# Steps          46
# Loves           0
# URL             0
# dtype: int64

# %%
df['Steps'].fillna('NoSteps', inplace=True)

# %%
df.isnull().sum()
# Out:
# Title          0
# Ingredients    0
# Steps          0
# Loves          0
# URL            0
# dtype: int64

# %%
df.head(10)
# Out:
#                                   Title  \
# 0   Orek tempe manis pedas super simple
# 1                Terik ayam tempe telor
# 2     Penyet Tempe Sambel Korek Kemangi
# 3                          Nugget tempe
# 4                   Tempe tepung sajiku
# 5                           Patty Tempe
# 6  Orek tempe basah bumbu ulek (recook)
# 7                        Perkedel Tempe
# 8                        Perkedel Tempe
# 9                   Nugget Tempe Simple
#
#                                          Ingredients  \
# 0  Tempe (saya beli 3000 saja)--3 buah cabe gendo...
# 1  4 sayap ayam--4 buah telor--1/2 papan tempe--B...
# 2  2 buah tempe--1 genggam Daun kemangi--15 cabe ...
# 3  1 papan tempe dihaluskan(saya kukus dlu)--1 bu...
# 4  1 potong tempe 3000--1 bngkus sajiku tepung se...
# 5  250 gram tempe, kukus, haluskan--150 gram dagi...
# 6  1 papan tempe, potong sesuai selera (sy 1/2 pa...
# 7  1/2 potong papan tempe (haluskan dgn sedikit a...
# 8  300 g tempe--1 butir telur, kocok lepas--1 btg...
# 9  1 papan tempe--1 buah wortel--1 butir telur (k...
#
#                                                Steps  Loves  \
# 0  Potong2 tempe sesuai selera lalu goreng sebent...      7
# 1  Cuci sayap ayam kemudian sisihkan. Rebus telur...      6
# 2  Iris tempe jd beberapa potong, bumbui dg bawan...      8
# 3  Campur tempe,wortel,daun bawang & bumbu yg sud...      8
# 4  Potong tempe tipis2--Tuang tepung lalu beri ai...      1
# 5  Ini tepung kobe putih yg sy pakai.--Campur sem...      9
# 6  Goreng tempe setengah matang, angkat, tiriskan...      6
# 7  Campurkan adonan tempe basah dengan bumbu halu...      1
# 8  Potong2 tempe, dan kukus selama 25 menit.--Hal...     11
# 9  Haluskan bawang merah, bawang putih, merica, g...      6
#
#                                                  URL
# 0  /id/resep/4474061-orek-tempe-manis-pedas-super...
# 1           /id/resep/4474066-terik-ayam-tempe-telor
# 2  /id/resep/4473809-penyet-tempe-sambel-korek-ke...
# 3                     /id/resep/4473715-nugget-tempe
# 4              /id/resep/4473463-tempe-tepung-sajiku
# 5                      /id/resep/4469642-patty-tempe
# 6  /id/resep/4473253-orek-tempe-basah-bumbu-ulek-...
# 7                   /id/resep/4473022-perkedel-tempe
# 8                   /id/resep/4448262-perkedel-tempe
# 9              /id/resep/4472907-nugget-tempe-simple

# %% [markdown]
# Memodifikasi dataframe untuk mendukung visualisasi:

# %% [markdown]
# 1. Menambahkan column 'numberof_Ingredients'

# %%
#membuat column baru dari berapa banyak pemisah "--" untuk menjadikan tolak ukur banyaknya bahan (numberof_Ingredients) 
df['numberof_Ingredients'] = df['Ingredients'].str.count('--')

# %%
df.head(10)
# Out:
#                                   Title  \
# 0   Orek tempe manis pedas super simple
# 1                Terik ayam tempe telor
# 2     Penyet Tempe Sambel Korek Kemangi
# 3                          Nugget tempe
# 4                   Tempe tepung sajiku
# 5                           Patty Tempe
# 6  Orek tempe basah bumbu ulek (recook)
# 7                        Perkedel Tempe
# 8                        Perkedel Tempe
# 9                   Nugget Tempe Simple
#
#                                          Ingredients  \
# 0  Tempe (saya beli 3000 saja)--3 buah cabe gendo...
# 1  4 sayap ayam--4 buah telor--1/2 papan tempe--B...
# 2  2 buah tempe--1 genggam Daun kemangi--15 cabe ...
# 3  1 papan tempe dihaluskan(saya kukus dlu)--1 bu...
# 4  1 potong tempe 3000--1 bngkus sajiku tepung se...
# 5  250 gram tempe, kukus, haluskan--150 gram dagi...
# 6  1 papan tempe, potong sesuai selera (sy 1/2 pa...
# 7  1/2 potong papan tempe (haluskan dgn sedikit a...
# 8  300 g tempe--1 butir telur, kocok lepas--1 btg...
# 9  1 papan tempe--1 buah wortel--1 butir telur (k...
#
#                                                Steps  Loves  \
# 0  Potong2 tempe sesuai selera lalu goreng sebent...      7
# 1  Cuci sayap ayam kemudian sisihkan. Rebus telur...      6
# 2  Iris tempe jd beberapa potong, bumbui dg bawan...      8
# 3  Campur tempe,wortel,daun bawang & bumbu yg sud...      8
# 4  Potong tempe tipis2--Tuang tepung lalu beri ai...      1
# 5  Ini tepung kobe putih yg sy pakai.--Campur sem...      9
# 6  Goreng tempe setengah matang, angkat, tiriskan...      6
# 7  Campurkan adonan tempe basah dengan bumbu halu...      1
# 8  Potong2 tempe, dan kukus selama 25 menit.--Hal...     11
# 9  Haluskan bawang merah, bawang putih, merica, g...      6
#
#                                                  URL  numberof_Ingredients
# 0  /id/resep/4474061-orek-tempe-manis-pedas-super...                    12
# 1           /id/resep/4474066-terik-ayam-tempe-telor                    19
# 2  /id/resep/4473809-penyet-tempe-sambel-korek-ke...                     6
# 3                     /id/resep/4473715-nugget-tempe                    10
# 4              /id/resep/4473463-tempe-tepung-sajiku                     4
# 5                      /id/resep/4469642-patty-tempe                     8
# 6  /id/resep/4473253-orek-tempe-basah-bumbu-ulek-...                    12
# 7                   /id/resep/4473022-perkedel-tempe                     8
# 8                   /id/resep/4448262-perkedel-tempe                     8
# 9              /id/resep/4472907-nugget-tempe-simple                     8

# %% [markdown]
# 2. Menambahkan column 'numberof_Steps'

# %%
#membuat column baru dari berapa banyak pemisah "--" untuk menjadikan tolak ukur banyaknya langkah (numberof_Steps) 
df['numberof_Steps'] = df['Steps'].str.count('--')

# %%
df.head(10)
# Out:
#                                   Title  \
# 0   Orek tempe manis pedas super simple
# 1                Terik ayam tempe telor
# 2     Penyet Tempe Sambel Korek Kemangi
# 3                          Nugget tempe
# 4                   Tempe tepung sajiku
# 5                           Patty Tempe
# 6  Orek tempe basah bumbu ulek (recook)
# 7                        Perkedel Tempe
# 8                        Perkedel Tempe
# 9                   Nugget Tempe Simple
#
#                                          Ingredients  \
# 0  Tempe (saya beli 3000 saja)--3 buah cabe gendo...
# 1  4 sayap ayam--4 buah telor--1/2 papan tempe--B...
# 2  2 buah tempe--1 genggam Daun kemangi--15 cabe ...
# 3  1 papan tempe dihaluskan(saya kukus dlu)--1 bu...
# 4  1 potong tempe 3000--1 bngkus sajiku tepung se...
# 5  250 gram tempe, kukus, haluskan--150 gram dagi...
# 6  1 papan tempe, potong sesuai selera (sy 1/2 pa...
# 7  1/2 potong papan tempe (haluskan dgn sedikit a...
# 8  300 g tempe--1 butir telur, kocok lepas--1 btg...
# 9  1 papan tempe--1 buah wortel--1 butir telur (k...
#
#                                                Steps  Loves  \
# 0  Potong2 tempe sesuai selera lalu goreng sebent...      7
# 1  Cuci sayap ayam kemudian sisihkan. Rebus telur...      6
# 2  Iris tempe jd beberapa potong, bumbui dg bawan...      8
# 3  Campur tempe,wortel,daun bawang & bumbu yg sud...      8
# 4  Potong tempe tipis2--Tuang tepung lalu beri ai...      1
# 5  Ini tepung kobe putih yg sy pakai.--Campur sem...      9
# 6  Goreng tempe setengah matang, angkat, tiriskan...      6
# 7  Campurkan adonan tempe basah dengan bumbu halu...      1
# 8  Potong2 tempe, dan kukus selama 25 menit.--Hal...     11
# 9  Haluskan bawang merah, bawang putih, merica, g...      6
#
#                                                  URL  numberof_Ingredients  \
# 0  /id/resep/4474061-orek-tempe-manis-pedas-super...                    12
# 1           /id/resep/4474066-terik-ayam-tempe-telor                    19
# 2  /id/resep/4473809-penyet-tempe-sambel-korek-ke...                     6
# 3                     /id/resep/4473715-nugget-tempe                    10
# 4              /id/resep/4473463-tempe-tepung-sajiku                     4
# 5                      /id/resep/4469642-patty-tempe                     8
# 6  /id/resep/4473253-orek-tempe-basah-bumbu-ulek-...                    12
# 7                   /id/resep/4473022-perkedel-tempe                     8
# 8                   /id/resep/4448262-perkedel-tempe                     8
# 9              /id/resep/4472907-nugget-tempe-simple                     8
#
#    numberof_Steps
# 0               3
# 1               3
# 2               5
# 3               4
# 4               6
# 5               7
# 6               3
# 7               3
# 8               4
# 9               4

# %% [markdown]
# VISUALIZATION

# %%
plt.figure(figsize=(12,5))

ax=sns.barplot(y=df.sort_values(by='Loves', ascending=False).head(10).Title, 
            x=df.sort_values(by='Loves', ascending=False).head(10).Loves,
           palette='Set2')

for p in ax.patches:
    width = p.get_width()
    plt.text(18+p.get_width(), p.get_y()+0.55*p.get_height(),
             '{:1.0f}'.format(width),
             ha='center', va='center')

sns.set(style='darkgrid')

plt.xticks()

plt.xlabel('Loves Count')
plt.ylabel('Food Recipe')
plt.title('Top 10 Most Loved Food Recipe', fontweight="bold")
plt.show()
# Out:
# /Users/gayatri/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 128537 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/gayatri/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 128076 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/gayatri/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 128077 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/gayatri/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 128069 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/gayatri/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 128537 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/gayatri/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 128076 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/gayatri/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 128077 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/gayatri/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 128069 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
plt.figure(figsize=(12,5))

ax = sns.barplot(y=df.sort_values(by='numberof_Ingredients', ascending=False).head(10).Title, 
                 x=df.sort_values(by='numberof_Ingredients', ascending=False).head(10).numberof_Ingredients,
                palette='Set2')

for p in ax.patches:
    width = p.get_width()
    plt.text(1+p.get_width(), p.get_y()+0.55*p.get_height(),
             '{:1.0f}'.format(width),
             ha='center', va='center')

sns.set(style='darkgrid')

plt.xticks()

plt.title('Top 10 Food Recipe with the most Ingredients', fontweight='bold')
plt.xlabel('Number of Ingredients')
plt.ylabel('Food Recipe')
plt.show()
# Out:
# /Users/gayatri/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 128513 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/gayatri/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 128513 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
plt.figure(figsize=(12,5))

ax=sns.barplot(y=df.sort_values(by='numberof_Steps', ascending=False).head(10).Title,
              x=df.sort_values(by='numberof_Steps', ascending=False).head(10).numberof_Steps,
              palette='Set2')

for p in ax.patches:
    width = p.get_width()
    plt.text(0.3+p.get_width(), p.get_y()+0.55*p.get_height(),
             '{:1.0f}'.format(width),
             ha='center', va='center')

sns.set(style='darkgrid')

plt.xticks()

plt.title('Top 10 Food Recipe with the most Steps/Difficult', fontweight='bold')
plt.xlabel('Number of Steps')
plt.ylabel('Food Recipe')
plt.show()

# %% [markdown]
# Most mentioned words in Ingredients:

# %%
text = df['Ingredients'].values

wordcloud = WordCloud(width = 800, height = 600,
            background_color ='white').generate(str(text))

plt.figure(figsize=(20,10))
plt.axis('off')
plt.imshow(wordcloud, interpolation='bilinear')
plt.show()

# %% [markdown]
# Most mentioned words in Steps:

# %%
text = df['Steps'].values

wordcloud = WordCloud(width = 800, height = 600,
                     background_color='white').generate(str(text))

plt.figure(figsize=(20,10))
plt.axis('off')
plt.imshow(wordcloud, interpolation='bilinear')
plt.show()
