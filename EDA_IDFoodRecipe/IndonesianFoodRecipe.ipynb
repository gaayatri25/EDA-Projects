# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
import glob
os.chdir("/directory")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/m7/kcpnk13922d03ts0552mzgj40000gn/T/ipykernel_85895/3351222082.py in <module>
#       5 import os
#       6 import glob
# ----> 7 os.chdir("/directory")
#
# FileNotFoundError: [Errno 2] No such file or directory: '/directory'

# %%
pwd
# Out:
# '/Users/gayatri/Documents/jupiter/datafood'

# %%
os.chdir('/Users/gayatri/Documents/jupiter/datafood')

# %%
ls
# Out:
# combined_datafood_csv.csv      dataset-sapi.csv
# combined_datafood_csv.numbers  dataset-tahu.csv
# dataset-ayam.csv               dataset-telur.csv
# dataset-ikan.csv               dataset-tempe.csv
# dataset-kambing.csv            dataset-udang.csv

# %%
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]

# %%
print(all_filenames)
# Out:
# ['dataset-tempe.csv', 'dataset-ayam.csv', 'dataset-udang.csv', 'dataset-kambing.csv', 'dataset-ikan.csv', 'dataset-telur.csv', 'dataset-tahu.csv', 'dataset-sapi.csv', 'combined_datafood_csv.csv']

# %%
combined_datafood_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])

# %%
print(combined_datafood_csv)
# Out:
#                                                    Title  \
# 0                    Orek tempe manis pedas super simple
# 1                                 Terik ayam tempe telor
# 2                      Penyet Tempe Sambel Korek Kemangi
# 3                                           Nugget tempe
# 4                                    Tempe tepung sajiku
# ...                                                  ...
# 15636  Bistik sapi empuk. Dengan tips memasak daging ...
# 15637                               Tongseng Daging Sapi
# 15638                               Sayur godog Iga sapi
# 15639                                    Sup daging sapi
# 15640                   Sop sayur tetelan daging sapi 🐄🐮
#
#                                              Ingredients  \
# 0      Tempe (saya beli 3000 saja)--3 buah cabe gendo...
# 1      4 sayap ayam--4 buah telor--1/2 papan tempe--B...
# 2      2 buah tempe--1 genggam Daun kemangi--15 cabe ...
# 3      1 papan tempe dihaluskan(saya kukus dlu)--1 bu...
# 4      1 potong tempe 3000--1 bngkus sajiku tepung se...
# ...                                                  ...
# 15636  1/2 kg daging sapi. Potong tipis melebar. Cuci...
# 15637  500 gr daging sapi (rebus hingga empuk)--1 rua...
# 15638  1/2 kg iga sapi--3 buah wortel--5 buah buncis-...
# 15639  1 kg daging sapi rebus--3 buah wortel iris2 ag...
# 15640  2 siung bawang putih--2 siung bawang merah--se...
#
#                                                    Steps  Loves  \
# 0      Potong2 tempe sesuai selera lalu goreng sebent...      7
# 1      Cuci sayap ayam kemudian sisihkan. Rebus telur...      6
# 2      Iris tempe jd beberapa potong, bumbui dg bawan...      8
# 3      Campur tempe,wortel,daun bawang & bumbu yg sud...      8
# 4      Potong tempe tipis2--Tuang tepung lalu beri ai...      1
# ...                                                  ...    ...
# 15636  Masukan daging dalam baskom. Tambahkan bumbu h...      9
# 15637  Tumis bumbu halus hingga harum, kemudian masuk...     30
# 15638  Rebus iga sampai setengah empuk sisihkan--Tumi...      3
# 15639  Rebus daging sampai empuk--Tumis bumbu halus s...     60
# 15640  Cuci bersih semua bahan-bahan--Haluskan bumbu ...      7
#
#                                                      URL
# 0      /id/resep/4474061-orek-tempe-manis-pedas-super...
# 1               /id/resep/4474066-terik-ayam-tempe-telor
# 2      /id/resep/4473809-penyet-tempe-sambel-korek-ke...
# 3                         /id/resep/4473715-nugget-tempe
# 4                  /id/resep/4473463-tempe-tepung-sajiku
# ...                                                  ...
# 15636  /id/resep/3362180-bistik-sapi-empuk-dengan-tip...
# 15637             /id/resep/3361383-tongseng-daging-sapi
# 15638             /id/resep/3361681-sayur-godog-iga-sapi
# 15639                  /id/resep/3361918-sup-daging-sapi
# 15640  /id/resep/3361226-sop-sayur-tetelan-daging-sap...
#
# [31282 rows x 5 columns]

# %%
pwd
# Out:
# '/Users/gayatri/Documents/jupiter/datafood'

# %%
combined_datafood_csv.to_csv( "combined_datafood_csv.csv", index=False, encoding='utf-8-sig')

# %%
df = pd.read_csv('combined_datafood_csv.csv')

# %%
df.head()
# Out:
#                                  Title  \
# 0  Orek tempe manis pedas super simple
# 1               Terik ayam tempe telor
# 2    Penyet Tempe Sambel Korek Kemangi
# 3                         Nugget tempe
# 4                  Tempe tepung sajiku
#
#                                          Ingredients  \
# 0  Tempe (saya beli 3000 saja)--3 buah cabe gendo...
# 1  4 sayap ayam--4 buah telor--1/2 papan tempe--B...
# 2  2 buah tempe--1 genggam Daun kemangi--15 cabe ...
# 3  1 papan tempe dihaluskan(saya kukus dlu)--1 bu...
# 4  1 potong tempe 3000--1 bngkus sajiku tepung se...
#
#                                                Steps  Loves  \
# 0  Potong2 tempe sesuai selera lalu goreng sebent...      7
# 1  Cuci sayap ayam kemudian sisihkan. Rebus telur...      6
# 2  Iris tempe jd beberapa potong, bumbui dg bawan...      8
# 3  Campur tempe,wortel,daun bawang & bumbu yg sud...      8
# 4  Potong tempe tipis2--Tuang tepung lalu beri ai...      1
#
#                                                  URL  numberof_Ingredients  \
# 0  /id/resep/4474061-orek-tempe-manis-pedas-super...                    12
# 1           /id/resep/4474066-terik-ayam-tempe-telor                    19
# 2  /id/resep/4473809-penyet-tempe-sambel-korek-ke...                     6
# 3                     /id/resep/4473715-nugget-tempe                    10
# 4              /id/resep/4473463-tempe-tepung-sajiku                     4
#
#    numberof_Steps
# 0               3
# 1               3
# 2               5
# 3               4
# 4               6

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15641 entries, 0 to 15640
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Title                 15641 non-null  object
#  1   Ingredients           15641 non-null  object
#  2   Steps                 15641 non-null  object
#  3   Loves                 15641 non-null  int64
#  4   URL                   15641 non-null  object
#  5   numberof_Ingredients  15641 non-null  int64
#  6   numberof_Steps        15641 non-null  int64
# dtypes: int64(3), object(4)
# memory usage: 855.5+ KB

# %%
df.shape
# Out:
# (15641, 7)

# %%
a = df.isnull().sum()
print(a)
# Out:
# Title                   0
# Ingredients             0
# Steps                   0
# Loves                   0
# URL                     0
# numberof_Ingredients    0
# numberof_Steps          0
# dtype: int64

# %%
df.isnull()
# Out:
#        Title  Ingredients  Steps  Loves    URL  numberof_Ingredients  \
# 0      False        False  False  False  False                 False
# 1      False        False  False  False  False                 False
# 2      False        False  False  False  False                 False
# 3      False        False  False  False  False                 False
# 4      False        False  False  False  False                 False
# ...      ...          ...    ...    ...    ...                   ...
# 15636  False        False  False  False  False                 False
# 15637  False        False  False  False  False                 False
# 15638  False        False  False  False  False                 False
# 15639  False        False  False  False  False                 False
# 15640  False        False  False  False  False                 False
#
#        numberof_Steps
# 0               False
# 1               False
# 2               False
# 3               False
# 4               False
# ...               ...
# 15636           False
# 15637           False
# 15638           False
# 15639           False
# 15640           False
#
# [15641 rows x 7 columns]

# %%
null_Ingredients = pd.isnull(df['Ingredients'])
print(null_Ingredients)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 15636    False
# 15637    False
# 15638    False
# 15639    False
# 15640    False
# Name: Ingredients, Length: 15641, dtype: bool

# %%
df['Ingredients'].isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 15636    False
# 15637    False
# 15638    False
# 15639    False
# 15640    False
# Name: Ingredients, Length: 15641, dtype: bool

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df[df['Ingredients'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Title, Ingredients, Steps, Loves, URL, numberof_Ingredients, numberof_Steps]
# Index: []

# %%
df[df['Steps'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Title, Ingredients, Steps, Loves, URL, numberof_Ingredients, numberof_Steps]
# Index: []

# %%
df[df['Title'].str.contains('Notitle', case=True)]
# Out:
#            Title    Ingredients    Steps  Loves  \
# 2241   [Notitle]  NoIngredients  NoSteps      0
# 2244   [Notitle]  NoIngredients  NoSteps      0
# 2284   [Notitle]  NoIngredients  NoSteps      0
# 2288   [Notitle]  NoIngredients  NoSteps      0
# 2450   [Notitle]  NoIngredients  NoSteps      0
# 2507   [Notitle]  NoIngredients  NoSteps      0
# 2509   [Notitle]  NoIngredients  NoSteps      0
# 2510   [Notitle]  NoIngredients  NoSteps      0
# 2821   [Notitle]  NoIngredients  NoSteps      0
# 2835   [Notitle]  NoIngredients  NoSteps      0
# 2836   [Notitle]  NoIngredients  NoSteps      0
# 2919   [Notitle]  NoIngredients  NoSteps      0
# 3065   [Notitle]  NoIngredients  NoSteps      0
# 3300   [Notitle]  NoIngredients  NoSteps      0
# 3785   [Notitle]  NoIngredients  NoSteps      0
# 6090   [Notitle]  NoIngredients  NoSteps      0
# 6152   [Notitle]  NoIngredients  NoSteps      0
# 6155   [Notitle]  NoIngredients  NoSteps      0
# 6156   [Notitle]  NoIngredients  NoSteps      0
# 6177   [Notitle]  NoIngredients  NoSteps      0
# 6532   [Notitle]  NoIngredients  NoSteps      0
# 6578   [Notitle]  NoIngredients  NoSteps      0
# 6712   [Notitle]  NoIngredients  NoSteps      0
# 6893   [Notitle]  NoIngredients  NoSteps      0
# 6994   [Notitle]  NoIngredients  NoSteps      0
# 7099   [Notitle]  NoIngredients  NoSteps      0
# 7406   [Notitle]  NoIngredients  NoSteps      0
# 7428   [Notitle]  NoIngredients  NoSteps      0
# 10029  [Notitle]  NoIngredients  NoSteps      0
# 10159  [Notitle]  NoIngredients  NoSteps      0
# 13689  [Notitle]  NoIngredients  NoSteps      0
# 13904  [Notitle]  NoIngredients  NoSteps      0
# 13915  [Notitle]  NoIngredients  NoSteps      0
# 14420  [Notitle]  NoIngredients  NoSteps      0
# 14446  [Notitle]  NoIngredients  NoSteps      0
# 14448  [Notitle]  NoIngredients  NoSteps      0
# 14449  [Notitle]  NoIngredients  NoSteps      0
# 14450  [Notitle]  NoIngredients  NoSteps      0
# 14451  [Notitle]  NoIngredients  NoSteps      0
# 14452  [Notitle]  NoIngredients  NoSteps      0
# 14466  [Notitle]  NoIngredients  NoSteps      0
# 14467  [Notitle]  NoIngredients  NoSteps      0
# 14590  [Notitle]  NoIngredients  NoSteps      0
# 14591  [Notitle]  NoIngredients  NoSteps      0
# 14592  [Notitle]  NoIngredients  NoSteps      0
# 14593  [Notitle]  NoIngredients  NoSteps      0
#
#                                                      URL  \
# 2241                        /id/resep/4459283-ayam-bakar
# 2244               /id/resep/4458951-sate-ayam-maknyusss
# 2284          /id/resep/4454787-garang-asam-ayam-kampung
# 2288                       /id/resep/4454903-ayam-kremes
# 2450                /id/resep/4444134-ayam-balado-simple
# 2507                     /id/resep/4442538-perkedel-ayam
# 2509        /id/resep/4442319-chicken-wings-saos-mentega
# 2510                   /id/resep/4442267-ayam-sambal-ijo
# 2821                    /id/resep/4410020-ayam-terriyaki
# 2835   /id/resep/4409498-mie-ayam-homemade-ala-mama-n...
# 2836   /id/resep/4409320-salted-egg-yolk-chicken-simp...
# 2919                           /id/resep/4396883-ayam-rw
# 3065                           /id/resep/4377584-mi-ayam
# 3300           /id/resep/4363996-ayam-gocap-goreng-kecap
# 3785                    /id/resep/4324179-sup-ceker-ayam
# 6090   /id/resep/3409967-sate-kambing-kecap-manis-sim...
# 6152   /id/resep/3334665-nasi-goreng-daur-ulang-gule-...
# 6155                /id/resep/3302954-gule-kambing-yummy
# 6156                     /id/resep/3302724-gulai-kambing
# 6177   /id/resep/3298588-nasi-kebuli-kambing-kitaberbagi
# 6532    /id/resep/3270914-nasgor-kambing-ala-kebon-sirih
# 6578                      /id/resep/3268926-sate-kambing
# 6712   /id/resep/2465947-nasi-kebuli-kambing-ala-bund...
# 6893                  /id/resep/1132705-tongseng-kambing
# 6994        /id/resep/967173-daging-kambing-bumbu-kuning
# 7099   /id/resep/955137-tumis-daging-kambing-setan-si...
# 7406                             /id/resep/4277212-maraq
# 7428    /id/resep/3918264-nasi-kebuli-ayam-ala-nusantara
# 10029  /id/resep/4395911-telor-ceplok-dicabein-kisahk...
# 10159              /id/resep/4361542-balado-telur-ceplok
# 13689         /id/resep/4471696-brokoli-sapi-cah-paprika
# 13904  /id/resep/4335141-tumis-daging-lemak-sapi-keto...
# 13915                /id/resep/4324037-nugget-udang-sapi
# 14420  /id/resep/3920063-beef-blackpaper-with-green-c...
# 14446         /id/resep/3905717-beef-teriyaki-ala-hokben
# 14448          /id/resep/3902717-sapi-lada-hitam-spesial
# 14449          /id/resep/3898125-beef-in-blackbean-sauce
# 14450                     /id/resep/3900516-rendang-sapi
# 14451       /id/resep/3900657-rendang-daging-sapi-simple
# 14452   /id/resep/3900664-gulai-kacang-merah-daging-sapi
# 14466                     /id/resep/3895985-rendang-sapi
# 14467  /id/resep/3895293-spaghetti-beef-marinara-pr_p...
# 14590  /id/resep/3812687-semur-tulang-daging-sapi-dan...
# 14591            /id/resep/3810864-oseng-kikil-sapi-tahu
# 14592                  /id/resep/3812346-sapi-lada-hitam
# 14593  /id/resep/3810985-bubur-lembut-sapi-slow-cooke...
#
#        numberof_Ingredients  numberof_Steps
# 2241                      0               0
# 2244                      0               0
# 2284                      0               0
# 2288                      0               0
# 2450                      0               0
# 2507                      0               0
# 2509                      0               0
# 2510                      0               0
# 2821                      0               0
# 2835                      0               0
# 2836                      0               0
# 2919                      0               0
# 3065                      0               0
# 3300                      0               0
# 3785                      0               0
# 6090                      0               0
# 6152                      0               0
# 6155                      0               0
# 6156                      0               0
# 6177                      0               0
# 6532                      0               0
# 6578                      0               0
# 6712                      0               0
# 6893                      0               0
# 6994                      0               0
# 7099                      0               0
# 7406                      0               0
# 7428                      0               0
# 10029                     0               0
# 10159                     0               0
# 13689                     0               0
# 13904                     0               0
# 13915                     0               0
# 14420                     0               0
# 14446                     0               0
# 14448                     0               0
# 14449                     0               0
# 14450                     0               0
# 14451                     0               0
# 14452                     0               0
# 14466                     0               0
# 14467                     0               0
# 14590                     0               0
# 14591                     0               0
# 14592                     0               0
# 14593                     0               0

# %%
df[df['Title'].str.contains('Notitle', case=True)]
# Out:
#            Title    Ingredients    Steps  Loves  \
# 2241   [Notitle]  NoIngredients  NoSteps      0
# 2244   [Notitle]  NoIngredients  NoSteps      0
# 2284   [Notitle]  NoIngredients  NoSteps      0
# 2288   [Notitle]  NoIngredients  NoSteps      0
# 2450   [Notitle]  NoIngredients  NoSteps      0
# 2507   [Notitle]  NoIngredients  NoSteps      0
# 2509   [Notitle]  NoIngredients  NoSteps      0
# 2510   [Notitle]  NoIngredients  NoSteps      0
# 2821   [Notitle]  NoIngredients  NoSteps      0
# 2835   [Notitle]  NoIngredients  NoSteps      0
# 2836   [Notitle]  NoIngredients  NoSteps      0
# 2919   [Notitle]  NoIngredients  NoSteps      0
# 3065   [Notitle]  NoIngredients  NoSteps      0
# 3300   [Notitle]  NoIngredients  NoSteps      0
# 3785   [Notitle]  NoIngredients  NoSteps      0
# 6090   [Notitle]  NoIngredients  NoSteps      0
# 6152   [Notitle]  NoIngredients  NoSteps      0
# 6155   [Notitle]  NoIngredients  NoSteps      0
# 6156   [Notitle]  NoIngredients  NoSteps      0
# 6177   [Notitle]  NoIngredients  NoSteps      0
# 6532   [Notitle]  NoIngredients  NoSteps      0
# 6578   [Notitle]  NoIngredients  NoSteps      0
# 6712   [Notitle]  NoIngredients  NoSteps      0
# 6893   [Notitle]  NoIngredients  NoSteps      0
# 6994   [Notitle]  NoIngredients  NoSteps      0
# 7099   [Notitle]  NoIngredients  NoSteps      0
# 7406   [Notitle]  NoIngredients  NoSteps      0
# 7428   [Notitle]  NoIngredients  NoSteps      0
# 10029  [Notitle]  NoIngredients  NoSteps      0
# 10159  [Notitle]  NoIngredients  NoSteps      0
# 13689  [Notitle]  NoIngredients  NoSteps      0
# 13904  [Notitle]  NoIngredients  NoSteps      0
# 13915  [Notitle]  NoIngredients  NoSteps      0
# 14420  [Notitle]  NoIngredients  NoSteps      0
# 14446  [Notitle]  NoIngredients  NoSteps      0
# 14448  [Notitle]  NoIngredients  NoSteps      0
# 14449  [Notitle]  NoIngredients  NoSteps      0
# 14450  [Notitle]  NoIngredients  NoSteps      0
# 14451  [Notitle]  NoIngredients  NoSteps      0
# 14452  [Notitle]  NoIngredients  NoSteps      0
# 14466  [Notitle]  NoIngredients  NoSteps      0
# 14467  [Notitle]  NoIngredients  NoSteps      0
# 14590  [Notitle]  NoIngredients  NoSteps      0
# 14591  [Notitle]  NoIngredients  NoSteps      0
# 14592  [Notitle]  NoIngredients  NoSteps      0
# 14593  [Notitle]  NoIngredients  NoSteps      0
#
#                                                      URL  \
# 2241                        /id/resep/4459283-ayam-bakar
# 2244               /id/resep/4458951-sate-ayam-maknyusss
# 2284          /id/resep/4454787-garang-asam-ayam-kampung
# 2288                       /id/resep/4454903-ayam-kremes
# 2450                /id/resep/4444134-ayam-balado-simple
# 2507                     /id/resep/4442538-perkedel-ayam
# 2509        /id/resep/4442319-chicken-wings-saos-mentega
# 2510                   /id/resep/4442267-ayam-sambal-ijo
# 2821                    /id/resep/4410020-ayam-terriyaki
# 2835   /id/resep/4409498-mie-ayam-homemade-ala-mama-n...
# 2836   /id/resep/4409320-salted-egg-yolk-chicken-simp...
# 2919                           /id/resep/4396883-ayam-rw
# 3065                           /id/resep/4377584-mi-ayam
# 3300           /id/resep/4363996-ayam-gocap-goreng-kecap
# 3785                    /id/resep/4324179-sup-ceker-ayam
# 6090   /id/resep/3409967-sate-kambing-kecap-manis-sim...
# 6152   /id/resep/3334665-nasi-goreng-daur-ulang-gule-...
# 6155                /id/resep/3302954-gule-kambing-yummy
# 6156                     /id/resep/3302724-gulai-kambing
# 6177   /id/resep/3298588-nasi-kebuli-kambing-kitaberbagi
# 6532    /id/resep/3270914-nasgor-kambing-ala-kebon-sirih
# 6578                      /id/resep/3268926-sate-kambing
# 6712   /id/resep/2465947-nasi-kebuli-kambing-ala-bund...
# 6893                  /id/resep/1132705-tongseng-kambing
# 6994        /id/resep/967173-daging-kambing-bumbu-kuning
# 7099   /id/resep/955137-tumis-daging-kambing-setan-si...
# 7406                             /id/resep/4277212-maraq
# 7428    /id/resep/3918264-nasi-kebuli-ayam-ala-nusantara
# 10029  /id/resep/4395911-telor-ceplok-dicabein-kisahk...
# 10159              /id/resep/4361542-balado-telur-ceplok
# 13689         /id/resep/4471696-brokoli-sapi-cah-paprika
# 13904  /id/resep/4335141-tumis-daging-lemak-sapi-keto...
# 13915                /id/resep/4324037-nugget-udang-sapi
# 14420  /id/resep/3920063-beef-blackpaper-with-green-c...
# 14446         /id/resep/3905717-beef-teriyaki-ala-hokben
# 14448          /id/resep/3902717-sapi-lada-hitam-spesial
# 14449          /id/resep/3898125-beef-in-blackbean-sauce
# 14450                     /id/resep/3900516-rendang-sapi
# 14451       /id/resep/3900657-rendang-daging-sapi-simple
# 14452   /id/resep/3900664-gulai-kacang-merah-daging-sapi
# 14466                     /id/resep/3895985-rendang-sapi
# 14467  /id/resep/3895293-spaghetti-beef-marinara-pr_p...
# 14590  /id/resep/3812687-semur-tulang-daging-sapi-dan...
# 14591            /id/resep/3810864-oseng-kikil-sapi-tahu
# 14592                  /id/resep/3812346-sapi-lada-hitam
# 14593  /id/resep/3810985-bubur-lembut-sapi-slow-cooke...
#
#        numberof_Ingredients  numberof_Steps
# 2241                      0               0
# 2244                      0               0
# 2284                      0               0
# 2288                      0               0
# 2450                      0               0
# 2507                      0               0
# 2509                      0               0
# 2510                      0               0
# 2821                      0               0
# 2835                      0               0
# 2836                      0               0
# 2919                      0               0
# 3065                      0               0
# 3300                      0               0
# 3785                      0               0
# 6090                      0               0
# 6152                      0               0
# 6155                      0               0
# 6156                      0               0
# 6177                      0               0
# 6532                      0               0
# 6578                      0               0
# 6712                      0               0
# 6893                      0               0
# 6994                      0               0
# 7099                      0               0
# 7406                      0               0
# 7428                      0               0
# 10029                     0               0
# 10159                     0               0
# 13689                     0               0
# 13904                     0               0
# 13915                     0               0
# 14420                     0               0
# 14446                     0               0
# 14448                     0               0
# 14449                     0               0
# 14450                     0               0
# 14451                     0               0
# 14452                     0               0
# 14466                     0               0
# 14467                     0               0
# 14590                     0               0
# 14591                     0               0
# 14592                     0               0
# 14593                     0               0

# %%
df['Ingredients'].fillna('NoIngredients', inplace=True)

# %%
df.isnull().sum()
# Out:
# Title                   0
# Ingredients             0
# Steps                   0
# Loves                   0
# URL                     0
# numberof_Ingredients    0
# numberof_Steps          0
# dtype: int64

# %%
df['Steps'].fillna('NoSteps', inplace=True)

# %%
df.isnull().sum()
# Out:
# Title                   0
# Ingredients             0
# Steps                   0
# Loves                   0
# URL                     0
# numberof_Ingredients    0
# numberof_Steps          0
# dtype: int64

# %%
df.head()
# Out:
#                                  Title  \
# 0  Orek tempe manis pedas super simple
# 1               Terik ayam tempe telor
# 2    Penyet Tempe Sambel Korek Kemangi
# 3                         Nugget tempe
# 4                  Tempe tepung sajiku
#
#                                          Ingredients  \
# 0  Tempe (saya beli 3000 saja)--3 buah cabe gendo...
# 1  4 sayap ayam--4 buah telor--1/2 papan tempe--B...
# 2  2 buah tempe--1 genggam Daun kemangi--15 cabe ...
# 3  1 papan tempe dihaluskan(saya kukus dlu)--1 bu...
# 4  1 potong tempe 3000--1 bngkus sajiku tepung se...
#
#                                                Steps  Loves  \
# 0  Potong2 tempe sesuai selera lalu goreng sebent...      7
# 1  Cuci sayap ayam kemudian sisihkan. Rebus telur...      6
# 2  Iris tempe jd beberapa potong, bumbui dg bawan...      8
# 3  Campur tempe,wortel,daun bawang & bumbu yg sud...      8
# 4  Potong tempe tipis2--Tuang tepung lalu beri ai...      1
#
#                                                  URL  numberof_Ingredients  \
# 0  /id/resep/4474061-orek-tempe-manis-pedas-super...                    12
# 1           /id/resep/4474066-terik-ayam-tempe-telor                    19
# 2  /id/resep/4473809-penyet-tempe-sambel-korek-ke...                     6
# 3                     /id/resep/4473715-nugget-tempe                    10
# 4              /id/resep/4473463-tempe-tepung-sajiku                     4
#
#    numberof_Steps
# 0               3
# 1               3
# 2               5
# 3               4
# 4               6

# %%
df
# Out:
#                                                    Title  \
# 0                    Orek tempe manis pedas super simple
# 1                                 Terik ayam tempe telor
# 2                      Penyet Tempe Sambel Korek Kemangi
# 3                                           Nugget tempe
# 4                                    Tempe tepung sajiku
# ...                                                  ...
# 15636  Bistik sapi empuk. Dengan tips memasak daging ...
# 15637                               Tongseng Daging Sapi
# 15638                               Sayur godog Iga sapi
# 15639                                    Sup daging sapi
# 15640                   Sop sayur tetelan daging sapi 🐄🐮
#
#                                              Ingredients  \
# 0      Tempe (saya beli 3000 saja)--3 buah cabe gendo...
# 1      4 sayap ayam--4 buah telor--1/2 papan tempe--B...
# 2      2 buah tempe--1 genggam Daun kemangi--15 cabe ...
# 3      1 papan tempe dihaluskan(saya kukus dlu)--1 bu...
# 4      1 potong tempe 3000--1 bngkus sajiku tepung se...
# ...                                                  ...
# 15636  1/2 kg daging sapi. Potong tipis melebar. Cuci...
# 15637  500 gr daging sapi (rebus hingga empuk)--1 rua...
# 15638  1/2 kg iga sapi--3 buah wortel--5 buah buncis-...
# 15639  1 kg daging sapi rebus--3 buah wortel iris2 ag...
# 15640  2 siung bawang putih--2 siung bawang merah--se...
#
#                                                    Steps  Loves  \
# 0      Potong2 tempe sesuai selera lalu goreng sebent...      7
# 1      Cuci sayap ayam kemudian sisihkan. Rebus telur...      6
# 2      Iris tempe jd beberapa potong, bumbui dg bawan...      8
# 3      Campur tempe,wortel,daun bawang & bumbu yg sud...      8
# 4      Potong tempe tipis2--Tuang tepung lalu beri ai...      1
# ...                                                  ...    ...
# 15636  Masukan daging dalam baskom. Tambahkan bumbu h...      9
# 15637  Tumis bumbu halus hingga harum, kemudian masuk...     30
# 15638  Rebus iga sampai setengah empuk sisihkan--Tumi...      3
# 15639  Rebus daging sampai empuk--Tumis bumbu halus s...     60
# 15640  Cuci bersih semua bahan-bahan--Haluskan bumbu ...      7
#
#                                                      URL  \
# 0      /id/resep/4474061-orek-tempe-manis-pedas-super...
# 1               /id/resep/4474066-terik-ayam-tempe-telor
# 2      /id/resep/4473809-penyet-tempe-sambel-korek-ke...
# 3                         /id/resep/4473715-nugget-tempe
# 4                  /id/resep/4473463-tempe-tepung-sajiku
# ...                                                  ...
# 15636  /id/resep/3362180-bistik-sapi-empuk-dengan-tip...
# 15637             /id/resep/3361383-tongseng-daging-sapi
# 15638             /id/resep/3361681-sayur-godog-iga-sapi
# 15639                  /id/resep/3361918-sup-daging-sapi
# 15640  /id/resep/3361226-sop-sayur-tetelan-daging-sap...
#
#        numberof_Ingredients  numberof_Steps
# 0                        12               3
# 1                        19               3
# 2                         6               5
# 3                        10               4
# 4                         4               6
# ...                     ...             ...
# 15636                    13              10
# 15637                    24               5
# 15638                    19               5
# 15639                    13               5
# 15640                    13               8
#
# [15641 rows x 7 columns]

# %%
plt.figure(figsize=(12,5))

ax=sns.barplot(y=df.sort_values(by='Loves', ascending=False).head(10).Title, 
            x=df.sort_values(by='Loves', ascending=False).head(10).Loves,
           palette='Set2')

for p in ax.patches:
    width = p.get_width()
    plt.text(18+p.get_width(), p.get_y()+0.55*p.get_height(),
             '{:1.0f}'.format(width),
             ha='center', va='center')

sns.set(style='darkgrid')

plt.xticks()

plt.xlabel('Loves Count')
plt.ylabel('Food Recipe')
plt.title('Top 10 Most Loved Food Recipe', fontweight="bold")
plt.show()
# Out:
# /Users/gayatri/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 128537 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/gayatri/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 128076 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/gayatri/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 128077 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/gayatri/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 128069 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/gayatri/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 128537 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/gayatri/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 128076 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/gayatri/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 128077 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/gayatri/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 128069 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
df['Ingredients'].str.len()
# Out:
# 0        197
# 1        337
# 2         88
# 3        318
# 4         96
#         ...
# 15636    328
# 15637    459
# 15638    437
# 15639    292
# 15640    214
# Name: Ingredients, Length: 15641, dtype: int64

# %%
df['Ingredients'].str.count('--')
# Out:
# 0        12
# 1        19
# 2         6
# 3        10
# 4         4
#          ..
# 15636    13
# 15637    24
# 15638    19
# 15639    13
# 15640    13
# Name: Ingredients, Length: 15641, dtype: int64

# %%
df['Ingredients'].str.count('--').sort_values(ascending=False).head(10)
# Out:
# 10997    77
# 10758    50
# 5687     48
# 12570    44
# 3617     41
# 7655     41
# 7519     39
# 7675     38
# 5927     38
# 7573     38
# Name: Ingredients, dtype: int64

# %%
df[['Title', 'Ingredients']]
# Out:
#                                                    Title  \
# 0                    Orek tempe manis pedas super simple
# 1                                 Terik ayam tempe telor
# 2                      Penyet Tempe Sambel Korek Kemangi
# 3                                           Nugget tempe
# 4                                    Tempe tepung sajiku
# ...                                                  ...
# 15636  Bistik sapi empuk. Dengan tips memasak daging ...
# 15637                               Tongseng Daging Sapi
# 15638                               Sayur godog Iga sapi
# 15639                                    Sup daging sapi
# 15640                   Sop sayur tetelan daging sapi 🐄🐮
#
#                                              Ingredients
# 0      Tempe (saya beli 3000 saja)--3 buah cabe gendo...
# 1      4 sayap ayam--4 buah telor--1/2 papan tempe--B...
# 2      2 buah tempe--1 genggam Daun kemangi--15 cabe ...
# 3      1 papan tempe dihaluskan(saya kukus dlu)--1 bu...
# 4      1 potong tempe 3000--1 bngkus sajiku tepung se...
# ...                                                  ...
# 15636  1/2 kg daging sapi. Potong tipis melebar. Cuci...
# 15637  500 gr daging sapi (rebus hingga empuk)--1 rua...
# 15638  1/2 kg iga sapi--3 buah wortel--5 buah buncis-...
# 15639  1 kg daging sapi rebus--3 buah wortel iris2 ag...
# 15640  2 siung bawang putih--2 siung bawang merah--se...
#
# [15641 rows x 2 columns]

# %%
df['numberof_Ingredients'] = df['Ingredients'].str.count('--')

# %%
df.head()
# Out:
#                                  Title  \
# 0  Orek tempe manis pedas super simple
# 1               Terik ayam tempe telor
# 2    Penyet Tempe Sambel Korek Kemangi
# 3                         Nugget tempe
# 4                  Tempe tepung sajiku
#
#                                          Ingredients  \
# 0  Tempe (saya beli 3000 saja)--3 buah cabe gendo...
# 1  4 sayap ayam--4 buah telor--1/2 papan tempe--B...
# 2  2 buah tempe--1 genggam Daun kemangi--15 cabe ...
# 3  1 papan tempe dihaluskan(saya kukus dlu)--1 bu...
# 4  1 potong tempe 3000--1 bngkus sajiku tepung se...
#
#                                                Steps  Loves  \
# 0  Potong2 tempe sesuai selera lalu goreng sebent...      7
# 1  Cuci sayap ayam kemudian sisihkan. Rebus telur...      6
# 2  Iris tempe jd beberapa potong, bumbui dg bawan...      8
# 3  Campur tempe,wortel,daun bawang & bumbu yg sud...      8
# 4  Potong tempe tipis2--Tuang tepung lalu beri ai...      1
#
#                                                  URL  numberof_Ingredients  \
# 0  /id/resep/4474061-orek-tempe-manis-pedas-super...                    12
# 1           /id/resep/4474066-terik-ayam-tempe-telor                    19
# 2  /id/resep/4473809-penyet-tempe-sambel-korek-ke...                     6
# 3                     /id/resep/4473715-nugget-tempe                    10
# 4              /id/resep/4473463-tempe-tepung-sajiku                     4
#
#    numberof_Steps
# 0               3
# 1               3
# 2               5
# 3               4
# 4               6

# %%
plt.figure(figsize=(12,5))

ax=sns.barplot(y=df.sort_values(by='numberof_Ingredients', ascending=False).head(10).Title,
              x=df.sort_values(by='numberof_Ingredients', ascending=False).head(10).numberof_Ingredients,
              palette='Set2')

for p in ax.patches:
    width = p.get_width()
    plt.text(1+p.get_width(), p.get_y()+0.55*p.get_height(),
             '{:1.0f}'.format(width),
             ha='center', va='center')

sns.set(style='darkgrid')

plt.xticks()

plt.title('Top 10 Food Recipe with the most Ingredients', fontweight='bold')
plt.xlabel('Number of Ingredients')
plt.ylabel('Food Recipe')
plt.show()
# Out:
# /Users/gayatri/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 128513 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/gayatri/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 128513 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
df['numberof_Steps'] = df['Steps'].str.count('--')

# %%
df.head()
# Out:
#                                  Title  \
# 0  Orek tempe manis pedas super simple
# 1               Terik ayam tempe telor
# 2    Penyet Tempe Sambel Korek Kemangi
# 3                         Nugget tempe
# 4                  Tempe tepung sajiku
#
#                                          Ingredients  \
# 0  Tempe (saya beli 3000 saja)--3 buah cabe gendo...
# 1  4 sayap ayam--4 buah telor--1/2 papan tempe--B...
# 2  2 buah tempe--1 genggam Daun kemangi--15 cabe ...
# 3  1 papan tempe dihaluskan(saya kukus dlu)--1 bu...
# 4  1 potong tempe 3000--1 bngkus sajiku tepung se...
#
#                                                Steps  Loves  \
# 0  Potong2 tempe sesuai selera lalu goreng sebent...      7
# 1  Cuci sayap ayam kemudian sisihkan. Rebus telur...      6
# 2  Iris tempe jd beberapa potong, bumbui dg bawan...      8
# 3  Campur tempe,wortel,daun bawang & bumbu yg sud...      8
# 4  Potong tempe tipis2--Tuang tepung lalu beri ai...      1
#
#                                                  URL  numberof_Ingredients  \
# 0  /id/resep/4474061-orek-tempe-manis-pedas-super...                    12
# 1           /id/resep/4474066-terik-ayam-tempe-telor                    19
# 2  /id/resep/4473809-penyet-tempe-sambel-korek-ke...                     6
# 3                     /id/resep/4473715-nugget-tempe                    10
# 4              /id/resep/4473463-tempe-tepung-sajiku                     4
#
#    numberof_Steps
# 0               3
# 1               3
# 2               5
# 3               4
# 4               6

# %%
df['Steps'].str.count('--').sort_values(ascending=False).head(10)
# Out:
# 15059    26
# 7501     25
# 7718     23
# 1341     23
# 10997    22
# 13701    21
# 13170    19
# 7620     19
# 7485     19
# 11513    18
# Name: Steps, dtype: int64

# %%
plt.figure(figsize=(12,5))

ax=sns.barplot(y=df.sort_values(by='numberof_Steps', ascending=False).head(10).Title,
              x=df.sort_values(by='numberof_Steps', ascending=False).head(10).numberof_Steps,
              palette='Set2')

for p in ax.patches:
    width = p.get_width()
    plt.text(0.3+p.get_width(), p.get_y()+0.55*p.get_height(),
             '{:1.0f}'.format(width),
             ha='center', va='center')

sns.set(style='darkgrid')

plt.xticks()

plt.title('Top 10 Food Recipe with the most Steps/Difficult', fontweight='bold')
plt.xlabel('Number of Steps')
plt.ylabel('Food Recipe')
plt.show()

# %%
text = df['Ingredients'].values

wordcloud = WordCloud(width = 800, height = 600,
            background_color ='white').generate(str(text))


#wordcloud = WordCloud(width = 800, height = 800, 
            #background_color ='white', 
            #stopwords = stopwords, 
            #min_font_size = 10).generate(comment_words)

plt.figure(figsize=(20,10))
plt.axis('off')
#plt.title('Most mentioned words in Ingredients', fontweight='bold')
#plt.tight_layout(pad=100)
plt.imshow(wordcloud, interpolation='bilinear')
plt.show()

# %%
from wordcloud import WordCloud

# %%
from nltk.corpus import stopwords

# %%
df['Ingredients']
# Out:
# 0        Tempe (saya beli 3000 saja)--3 buah cabe gendo...
# 1        4 sayap ayam--4 buah telor--1/2 papan tempe--B...
# 2        2 buah tempe--1 genggam Daun kemangi--15 cabe ...
# 3        1 papan tempe dihaluskan(saya kukus dlu)--1 bu...
# 4        1 potong tempe 3000--1 bngkus sajiku tepung se...
#                                ...
# 15636    1/2 kg daging sapi. Potong tipis melebar. Cuci...
# 15637    500 gr daging sapi (rebus hingga empuk)--1 rua...
# 15638    1/2 kg iga sapi--3 buah wortel--5 buah buncis-...
# 15639    1 kg daging sapi rebus--3 buah wortel iris2 ag...
# 15640    2 siung bawang putih--2 siung bawang merah--se...
# Name: Ingredients, Length: 15641, dtype: object

# %%
df['Ingredients'].values
# Out:
# array(['Tempe (saya beli 3000 saja)--3 buah cabe gendot--3 buah cabe keriting--3 buah cabe rawit merah--2 siung bawang merah--1 siung bawang putih--Kecap--Saus tiram--Saus tomat--Kaldu bubuk--Garam--Gula--',
#        '4 sayap ayam--4 buah telor--1/2 papan tempe--Bumbu halus:--5 siung bawang merah--4 siung bawang putih--2 butir kemiri--1/2 sdm ketumbar--secukupnya Garam--Bumbu lain:--2 cm lengkuas--1 lembar daun salam--1 batang sereh--secukupnya Gula jawa--Bawang goreng--Minyak untuk menumis--1 bungkus santan kara--secukupnya Air--5 buah cabe rawit--',
#        '2 buah tempe--1 genggam Daun kemangi--15 cabe rawit--2 siung bawang putih--Gula--Garam--',
#        ...,
#        '1/2 kg iga sapi--3 buah wortel--5 buah buncis--2 buah labu siam,aku pake yg muda ajah--1 btg daun bawang--2 buah cabe ijo besar--1 buah cabe merah besar--5 buah cabe rawit merah--1/2 butir kelapa (santan)--3 lbr daun salam--seibu jari lengkuas digeprek--2 lbr daun jeruk disobek tengahnya--Bumbu Halus :--6 buah cabe merah kriting--5 buah bawang merah--3 buah bawang putih--seruas jempol kunyit--1 sendok makan ebi--Garam Gula penyedap--',
#        '1 kg daging sapi rebus--3 buah wortel iris2 agak tebal--4 buah kentang iris2 agak tebal juga--Daun bawang--Daun seledri--Bumbu halus :--3 siung bawang putih--2 siung bawang merah--Pala bubuk secukup nya--Lada secukup nya--Garam secukup nya--Gula (secukup nya)--Bawang goreng (untuk ditabur)--',
#        '2 siung bawang putih--2 siung bawang merah--secukupnya Kemiri, merica, garam, penyedap rasa--secukupnya Lengkuas--secukupnya Air--Tetelan daging sapi--Kubis--Wortel--Daun bawang--Tomat--Kara--Seledri--Kembang kol--'],
#       dtype=object)

# %%
df['Ingredients'].index
# Out:
# RangeIndex(start=0, stop=15641, step=1)

# %%
from nltk.corpus import stopwords

# %%
text = df['Title'].values

wordcloud = WordCloud(width = 800, height = 600,
            background_color ='white').generate(str(text))


#wordcloud = WordCloud(width = 800, height = 800, 
            #background_color ='white', 
            #stopwords = stopwords, 
            #min_font_size = 10).generate(comment_words)

plt.figure(figsize=(20,10))
plt.axis('off')
#plt.title('Most mentioned words in Ingredients', fontweight='bold')
#plt.tight_layout(pad=100)
plt.imshow(wordcloud, interpolation='bilinear')
plt.show()
